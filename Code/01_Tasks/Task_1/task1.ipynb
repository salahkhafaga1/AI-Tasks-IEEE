# %%
def matsum(arr1, arr2):
    result = []
    for i in range(len(arr1)):
        row = []
        for j in range(len(arr1[0])):
            row.append(arr1[i][j] + arr2[i][j])
        result.append(row)
    return result

# %%
def matsub(arr1, arr2):
    result = []
    for i in range(len(arr1)):
        row = []
        for j in range(len(arr1[0])):
            row.append(arr1[i][j] - arr2[i][j])
        result.append(row)
    return result

# %%
def matmul(arr1, arr2):
    result = []
    for i in range(len(arr1)):
        row = []
        for j in range(len(arr2[0])):
            sum_product = 0
            for k in range(len(arr2)):
                sum_product += arr1[i][k] * arr2[k][j]
            row.append(sum_product)
        result.append(row)
    return result

# %%
def scalarsum(scalar, arr):
    result = []
    for i in range(len(arr)):
        row = []
        for j in range(len(arr[0])):
            row.append(arr[i][j] + scalar)
        result.append(row)
    return result

# %%
def scalarsub(scalar, arr):
    result = []
    for i in range(len(arr)):
        row = []
        for j in range(len(arr[0])):
            row.append(arr[i][j] - scalar)
        result.append(row)
    return result

# %%
def scalarmul(scalar, arr):
    result = []
    for i in range(len(arr)):
        row = []
        for j in range(len(arr[0])):
            row.append(arr[i][j] * scalar)
        result.append(row)
    return result

# %%
def matnorm(arr):
    flat_list = []
    for row in arr:
        for val in row:
            flat_list.append(val)
            
    min_val = min(flat_list)
    max_val = max(flat_list)
    diff = max_val - min_val

    result = []
    for i in range(len(arr)):
        row = []
        for j in range(len(arr[0])):
            if diff == 0:
                row.append(0.0)
            else:
                norm_value = (arr[i][j] - min_val) / diff
                
                row.append(round(norm_value, 2))
        result.append(row)
    return result

# %%
import os

# 1. تعريف الهيكل الأساسي للفولدرات
folders = [
    "01_Tasks/Task_1_Math_and_Normalization",
    "02_Projects",
    "03_Notes_and_Resources"
]

# 2. إنشاء الفولدرات
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"✅ Created folder: {folder}")

# 3. محتوى ملف الـ README الأساسي
readme_content = """# 🤖 IEEE AI Tasks & Projects

Welcome to my personal workspace for the IEEE Artificial Intelligence Committee! This repository is dedicated to tracking my progress, organizing machine learning assignments, and documenting data science projects.

## 👨‍💻 About
Hi, I'm **Hossam El-Din**! I'm passionate about developing smart AI solutions, exploring data preprocessing, and building projects that make a real impact—whether it's participating in hackathons or creating practical applications.

## 📂 Repository Structure

- **`01_Tasks/`**: Contains regular AI committee assignments and foundational concepts.
- **`02_Projects/`**: Houses larger, end-to-end machine learning and deep learning projects.
- **`03_Notes_and_Resources/`**: Personal summaries, cheat sheets, and educational materials.

## 🛠️ Tech Stack & Tools
* **Languages:** Python
* **Libraries:** NumPy, Pandas, Scikit-Learn, Matplotlib
* **Tools:** Jupyter Notebook, Git
"""

# 4. إنشاء ملف README.md الأساسي
with open("README.md", "w", encoding="utf-8") as f:
    f.write(readme_content)
print("✅ Created README.md")

# 5. إنشاء ملفات بايثون لتاسك اليوم عشان تكتب فيها الأكواد
task_files = [
    "01_Tasks/Task_1_Math_and_Normalization/trapezoid_rule.py",
    "01_Tasks/Task_1_Math_and_Normalization/matrix_normalization.py",
    "01_Tasks/Task_1_Math_and_Normalization/README.md"
]

for file in task_files:
    # إنشاء ملفات فاضية أو بداخلها تعليق بسيط
    with open(file, "w", encoding="utf-8") as f:
        if file.endswith(".py"):
            f.write("# Write your python code here\n")
        else:
            f.write("# Task 1: Math and Normalization\n\nAdd your task notes here.")
    print(f"✅ Created file: {file}")

print("\n🎉 تم إنشاء هيكل الملفات بنجاح! فولدرك جاهز دلوقتي.")
# Out:
# ✅ Created folder: 01_Tasks/Task_1_Math_and_Normalization
# ✅ Created folder: 02_Projects
# ✅ Created folder: 03_Notes_and_Resources
# ✅ Created README.md
# ✅ Created file: 01_Tasks/Task_1_Math_and_Normalization/trapezoid_rule.py
# ✅ Created file: 01_Tasks/Task_1_Math_and_Normalization/matrix_normalization.py
# ✅ Created file: 01_Tasks/Task_1_Math_and_Normalization/README.md
#
# 🎉 تم إنشاء هيكل الملفات بنجاح! فولدرك جاهز دلوقتي.
