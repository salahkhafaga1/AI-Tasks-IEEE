# %% [markdown]
# # Titanic Dataset Analysis - IEEE SSCS | AI Sub-Team
# ## Introduction
# This notebook contains a complete data analysis pipeline for the Titanic dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1: Load the Data
# Our starting point. We get the data into the environment and take the first look at what we are working with.

# %%
# Load the dataset
df = pd.read_csv('./titanic.csv')

# Display a random sample of 5 rows
display(df.sample(5))
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 562          563         0       2            Norman, Mr. Robert Douglas
# 552          553         0       3                  O'Brien, Mr. Timothy
# 309          310         1       1        Francatelli, Miss. Laura Mabel
# 93            94         0       3               Dean, Mr. Bertram Frank
# 541          542         0       3  Andersson, Miss. Ingeborg Constanzia
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 562    male  28.0      0      0     218629  13.5000   NaN        S
# 552    male   NaN      0      0     330979   7.8292   NaN        Q
# 309  female  30.0      0      0   PC 17485  56.9292   E36        C
# 93     male  26.0      1      2  C.A. 2315  20.5750   NaN        S
# 541  female   9.0      4      2     347082  31.2750   NaN        S

# %% [markdown]
# ## Step 2: Data Cleaning
# Real data is messy. Here we will:
# 1. Drop irrelevant columns (`PassengerId`, `Name`, `Ticket`, `Cabin`).
# 2. Fix data types for better memory usage.
# 3. Handle missing values (e.g., filling `Age` with the median).
# 4. Handle Outliers using the IQR method.
# 5. Remove duplicates.

# %%
# 1. Drop irrelevant columns
columns_to_drop = ['PassengerId', 'Name', 'Ticket', 'Cabin']
df.drop(columns_to_drop, axis=1, inplace=True)

# 2. Optimize data types (convert categorical columns to 'category')
categorical_cols = ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']
df[categorical_cols] = df[categorical_cols].astype('category')

# 3. Handle missing values
# Fill missing 'Age' with the median
median_age = df['Age'].median()
df['Age'].fillna(median_age, inplace=True)

# Fill missing 'Embarked' with the mode
mode_embarked = df['Embarked'].mode()[0]
df['Embarked'].fillna(mode_embarked, inplace=True)
# Check missing values after cleaning
print("Missing values after cleaning:\n", df.isnull().sum())
# Out:
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 1 columns]
# Missing values after cleaning:
#  Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### Handling Outliers
# We will check for continuous numerical columns and cap the outliers using the Interquartile Range (IQR) method.

# %%
# Identify continuous numerical columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Cap outliers using Lower and Upper Fences
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_fence = Q1 - 1.5 * IQR
    upper_fence = Q3 + 1.5 * IQR
    
    # Replace outliers with fence values
    df[col] = np.where(df[col] < lower_fence, lower_fence, df[col])
    df[col] = np.where(df[col] > upper_fence, upper_fence, df[col])

# Remove duplicates
df.drop_duplicates(inplace=True)
print("Data shape after dropping duplicates:", df.shape)
# Out:
# Data shape after dropping duplicates: (762, 8)

# %% [markdown]
# ## Step 3: Exploratory Data Analysis (EDA)
# Digging in. Let's see what patterns, distributions, or relationships we can find using visualizations.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# 1. Survival by Gender
sns.countplot(data=df, x='Sex', hue='Survived', palette='Set2', ax=axes[0])
axes[0].set_title('Survival Count by Gender')

# 2. Survival by Passenger Class
sns.countplot(data=df, x='Pclass', hue='Survived', palette='Set1', ax=axes[1])
axes[1].set_title('Survival Count by Passenger Class')

# 3. Age Distribution
sns.histplot(data=df, x='Age', hue='Survived', kde=True, bins=30)
axes[2].set_title('Age Distribution by Survival')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Analysis & Insights
# Going deeper. Let's look at the correlation between variables and extract statistical insights.

# %%
# Correlation Matrix
plt.figure(figsize=(8, 6))

# Prepare data for correlation (converting categories back to numeric temporarily)
heatmap_data = df.copy()
heatmap_data['Survived'] = heatmap_data['Survived'].astype(int)
heatmap_data['Pclass'] = heatmap_data['Pclass'].astype(int)
numeric_cols = heatmap_data.select_dtypes(include=[np.number])

sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Titanic Features')
plt.show()

# %%
# Survival Rate by Class and Gender
pivot_insight = pd.pivot_table(df, values='Survived', index='Pclass', columns='Sex', aggfunc=lambda x: x.astype(int).mean() * 100)
print(f"Survival Rate (%) by Class and Gender:")
display(pivot_insight.round(2))
# Out:
# Survival Rate (%) by Class and Gender:
# Sex     female   male
# Pclass
# 1        96.51  37.72
# 2        91.67  18.68
# 3        47.24  16.18

# %% [markdown]
# ## Step 5 Final Insights via Pandas

# %%
# Insight 1: Survival Rate by Gender
print("\n1. Survival Rate by Gender:")

# Filter only females and calculate their average survival
females = df[df['Sex'] == 'female'] 

# astype(int)to Category
female_survival = females['Survived'].astype(int).mean() * 100
print("Female Survival Rate:", round(female_survival, 1), "%")

# Filter only males and calculate their average survival
males = df[df['Sex'] == 'male']
male_survival = males['Survived'].astype(int).mean() * 100
print("Male Survival Rate:", round(male_survival, 1), "%")
# Out:
# 1. Survival Rate by Gender:
# Female Survival Rate: 73.3 %
# Male Survival Rate: 21.8 %

# %%
# Insight 2: Survival Rate by Passenger Class
print("\n2. Survival Rate by Passenger Class:")

# Calculate survival for each class separately
class_1 = df[df['Pclass'] == 1]
class_1_survival = class_1['Survived'].astype(int).mean() * 100
print("Class 1 Survival Rate:", round(class_1_survival, 1), "%")

class_2 = df[df['Pclass'] == 2]
class_2_survival = class_2['Survived'].astype(int).mean() * 100
print("Class 2 Survival Rate:", round(class_2_survival, 1), "%")

class_3 = df[df['Pclass'] == 3]
class_3_survival = class_3['Survived'].astype(int).mean() * 100
print("Class 3 Survival Rate:", round(class_3_survival, 1), "%")
# Out:
# 2. Survival Rate by Passenger Class:
# Class 1 Survival Rate: 63.0 %
# Class 2 Survival Rate: 50.9 %
# Class 3 Survival Rate: 26.1 %

# %%
# Insight 3: Ticket Fare and Survival
print("\n3. Average Fare by Survival:")

# Separate the passengers who survived from those who died

survivors = df[df['Survived'].astype(int) == 1]
non_survivors = df[df['Survived'].astype(int) == 0]

# Calculate the average ticket price for both groups (Fare is already a number)
avg_fare_survived = survivors['Fare'].mean()
avg_fare_died = non_survivors['Fare'].mean()

print("Average Fare for Survivors: ", round(avg_fare_survived, 2),'$')
print("Average Fare for Non-Survivors: ", round(avg_fare_died, 2),'$')
# Out:
# 3. Average Fare by Survival:
# Average Fare for Survivors:  32.37 $
# Average Fare for Non-Survivors:  20.17 $

# %% [markdown]
# ## Step 6: Conclusion
# **Key Takeaways:**
# 1. **Gender Impact:** The "Women and children first" protocol was clearly executed. Females had a significantly higher survival rate compared to males.
# 2. **Socio-economic Status:** Passenger class heavily influenced survival. First-class passengers had priority access to lifeboats, resulting in the highest survival rate, while Third-class passengers suffered the most casualties.
# 3. **Correlation:** There is a strong relationship between the fare paid, the passenger class, and the likelihood of survival.
